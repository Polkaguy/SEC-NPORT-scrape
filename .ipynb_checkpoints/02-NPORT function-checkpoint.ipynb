# %%
import pandas as pd
import requests
from xml.etree import ElementTree as ET
from bs4 import BeautifulSoup

# %% [markdown]
# The information in this document takes an XML target for an NPORT form and returns information about it.
#
# <hr>
# The following block of code imports the pickle file from 01 then selects a sample. The sample is selected randomly, but by setting the seed, the sample will the be same each time this block of code is run.

# %%
df = pd.read_pickle('Investment Company Series and Class Information.p')
sample = df.sample(random_state=35)
sample
# Out:
#       reporting_file_number         cik entity_name entity_org_type  \
# 15962             811-04347  0000772129   GMO TRUST              30
#
#         series_id                       series_name    class_id class_name  \
# 15962  S000005487  GMO Global Asset Allocation Fund  C000213377    Class I
#
#       class_ticker       address_1    city zip_code state address_2
# 15962       [NULL]  40 ROWES WHARF  BOSTON    02110    MA    [NULL]

# %% [markdown]
# I manually found an example N-PORT filing for this company. This example is the [NPORT monthly filing from November 30, 2019](https://www.sec.gov/Archives/edgar/data/772129/000175272420015077/0001752724-20-015077-index.htm). This block of code imports that into an ElementTree

# %%
link = 'https://www.sec.gov/Archives/edgar/data/772129/000175272420015077/primary_doc.xml'
r = requests.get(link)
assert(r), r
xml = ET.fromstring(r.text)

# %% [markdown]
# In this block of code, I build the portion of the function that accepts the xml ElementTree then extracts information about the investments --`invstOrSecs`--they hold.

# %%
secs = xml.find('{http://www.sec.gov/edgar/nport}formData').find('{http://www.sec.gov/edgar/nport}invstOrSecs')
all_secs = []
for s in secs:
    t_dict = {}
    for e in s:
        # [32:] trims {http://www.sec.gov/edgar/nport} from tag
        t_dict[e.tag[32:]] = e.text 
    all_secs += [t_dict]
res = pd.DataFrame(all_secs)
        

res.head()
# Out:
#                  name                   lei               title      cusip  \
# 0          Ebara Corp  353800UV8U3SOMCDTI49          Ebara Corp  000000000
# 1      Bakkafrost P/F  2138007LH7OP4V112978      Bakkafrost P/F  000000000
# 2    METAWATER Co Ltd                   N/A    METAWATER Co Ltd  000000000
# 3  Tongaat Hulett Ltd                   N/A  Tongaat Hulett Ltd  000000000
# 4         Exelon Corp  3SOUA6IRML7435B56G12         Exelon Corp  30161N101
#
#     identifiers         balance units  currencyConditional            valUSD  \
# 0  \n            35900.00000000    NS                  NaN  1080297.91000000
# 1  \n              704.00000000    NS                  NaN    47197.02000000
# 2  \n             4300.00000000    NS                  NaN   156886.67000000
# 3  \n            19722.00000000    NS                  NaN     8891.42000000
# 4  \n            26500.00000000    NS                  NaN  1176600.00000000
#
#            pctVal payoffProfile assetCat issuerCat invCountry isRestrictedSec  \
# 0  0.915718983734          Long       EC      CORP         JP               N
# 1  0.040006748869          Long       EC      CORP         FO               N
# 2  0.132985633577          Long       EC      CORP         JP               N
# 3  0.007536848873          Long       EC      CORP         ZA               N
# 4  0.997349847934          Long       EC      CORP         US               N
#
#   fairValLevel securityLending curCd  issuerConditional derivativeInfo
# 0            2    \n             NaN                NaN            NaN
# 1            2    \n             NaN                NaN            NaN
# 2            2    \n             NaN                NaN            NaN
# 3            3    \n             NaN                NaN            NaN
# 4            1    \n             USD                NaN            NaN
